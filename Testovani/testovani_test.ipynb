# %% [markdown]
# Uprav třídu Calculator tak, aby:
#
# 1. Každá metoda kontrolovala typ vstupů.
#
#   * Pokud některý z parametrů není číslo (int nebo float), metoda má:
#
#     * vyvolat výjimku TypeError
#
# 2. Metoda divide navíc:
#
#     * při dělení nulou má vyvolat ZeroDivisionError (už ne vracet None)
#
# 3. Celkově tedy třída musí správně ošetřit:
#
#   * neplatný datový typ
#
#   * dělení nulou
#
# * A testy musí ověřit:
#
#   * správnost sčítání
#
#   * dělení nulou → ZeroDivisionError
#
#   * použití nečíselného vstupu → TypeError
#
#   * složenou operaci s validními čísly

# %%
# TODO: implementujte kód podle zadání do souboru přiloženým v zadání
class Calculator:
    def _check_numbers(self, a, b):
        pass

    def add(self, a, b):
        pass

    def subtract(self, a, b):
        pass

    def multiply(self, a, b):
        pass

    def divide(self, a, b):
       pass

# %% [markdown]
# Vytvořte třídu TestCalculator dle zadání

# %%
#TODO vytvořte třídu TestCalculator dle zadání
