# %% [markdown]
# 1️⃣ DEBUG logger – vypisuje do konzole
#
# Slouží pro podrobné informace o průběhu programu.
#
# Zapíše se vždy při:
#
# * změně skóre
#
# * kontrole výhry (včetně podrobností)
#
# 2️⃣ INFO logger – zapisuje do souboru log_info.txt
#
# Slouží pro uživatelsky důležité události.
#
# Zapíše se vždy při:
#
# * vytvoření hráče
#
# * změně skóre
#
# * kontrole výhry

# %% [markdown]
# Úkol 1:
#
# * Nastav logger DEBUG, který bude vypisovat logy do konzole.
#
# Úkol 2:
#
# * Nastav logger INFO, který bude zapisovat události do souboru log_info.txt.
#
# Úkol 3:
#
# * Nastav logger INFO, aby ukládal log ve formátu: [98-11-20 07:02] zpráva.
#
# Úkol 4:
#
# Doplň metody:
#
# * pridat_body(body) – přidá body a zaloguje události
#
# * zkontrolovat_vyhru(limit) – vrátí True/False a zapíše výsledky do logu

# %%
import logging
import sys

class Hrac:
    def __init__(self, jmeno):
        self.jmeno = jmeno
        self.skore = 0

    def pridat_body(self, body):
        stary_stav = self.skore
        self.skore += body

    def zkontrolovat_vyhru(self, limit):
        if self.skore >= limit:
            return True
        else:
            return False


if __name__ == "__main__":
    hrac = Hrac("Petr")
    hrac.pridat_body(5)
    hrac.pridat_body(10)
    hrac.zkontrolovat_vyhru(10)
