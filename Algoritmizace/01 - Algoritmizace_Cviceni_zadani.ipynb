# %% [markdown]
# # ✏️ Algoritmizace – Cvičení: Vývojové diagramy
#
# V každém cvičení nakreslete **vývojový diagram** pro popsaný problém.
#
#
# > 💡 Nakreslete diagram do buňky níže jako text (ASCII art), nebo ho nakreslete na papír/do draw.io.

# %% [markdown]
# ---
#
# ## 🟢 Cvičení 1 – Pozdrav podle denní doby
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte aktuální hodinu (0–23)
# 2. Pokud je hodina menší než 12, vypíše `"Dobré ráno!"`
# 3. Jinak vypíše `"Dobré odpoledne!"`

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🟢 Cvičení 2 – Největší ze dvou čísel
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte dvě čísla: `a` a `b`
# 2. Porovná je a vypíše, které je větší
# 3. Pokud jsou stejná, vypíše `"Čísla jsou stejná"`

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🟡 Cvičení 3 – Klasifikace známky
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte číselnou známku (1–5)
# 2. Vypíše odpovídající slovní hodnocení:
#    - 1 → `"Výborný"`
#    - 2 → `"Chvalitebný"`
#    - 3 → `"Dobrý"`
#    - 4 → `"Dostatečný"`
#    - 5 → `"Nedostatečný"`
#    - jiné → `"Neplatná známka"`
#
# > 💡 Budete potřebovat více podmínek za sebou.

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🟡 Cvičení 4 – Odpočítávání
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte číslo `n`
# 2. Vypíše čísla od `n` do `1` (sestupně)
# 3. Na konci vypíše `"Start!"`
#
# **Příklad** (pro n = 5):
# ```
# 5
# 4
# 3
# 2
# 1
# Start!
# ```
#
# > 💡 Potřebujete cyklus – opakujte kroky, dokud číslo neklesne na 0.

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🟡 Cvičení 5 – Součet čísel od 1 do n
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte číslo `n`
# 2. Spočítá součet všech čísel od 1 do n
# 3. Vypíše výsledek
#
# **Příklad** (pro n = 4):
# `1 + 2 + 3 + 4 = 10`

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🔴 Cvičení 6 – Dělitelnost
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. Přečte číslo od uživatele
# 2. Zkontroluje, zda je číslo dělitelné 3, dělitelné 5, nebo oběma
# 3. Vypíše:
#    - `"FizzBuzz"` – pokud je dělitelné oběma (3 i 5)
#    - `"Fizz"` – pokud je dělitelné jen 3
#    - `"Buzz"` – pokud je dělitelné jen 5
#    - samotné číslo – pokud není dělitelné ani jedním
#
# > 💡 Tip: Nejprve ověřte dělitelnost oběma čísly dohromady.

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC

# %% [markdown]
# ---
#
# ## 🔴 Cvičení 7 – Hádání čísla
#
# Nakreslete vývojový diagram pro algoritmus, který:
# 1. „Zná
# 42
# ,
# 2
# ,
# 3
# Větší!"`
# 4. Pokud je tip větší, vypíše `"Menší!"`
# 5. Pokud uhodl, vypíše `"Správně!"` a skončí
#
# > 💡 Potřebujete cyklus, který se opakuje, dokud uživatel neuhodne.

# %% [markdown]
# ### Vaše řešení:

# %%
# Nakreslete vývojový diagram jako komentář:
#
#   START
#    ...
#   KONEC
